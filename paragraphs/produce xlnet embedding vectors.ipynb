# %%
from transformers import XLNetTokenizer, XLNetModel
import numpy as np
import torch
import pandas as pd
from tqdm import tqdm

# %%
# Load XLNet tokenizer and model
tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased')
model = XLNetModel.from_pretrained('xlnet-base-cased')
# Out:
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/760 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetModel: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
doc = 'Position the assembled console on the favored place in opposition to a wall. If necessary, modify the pre-connected Floor Levelers at the lowest of Legs (F and G) to stage the unit. Now, comply with the commands imprinted on the plastic bag containing the Tipping Restraint Hardware to connect the tip-over restraint to the Top Metal Frame (A) and the wall. NOTE: YOU MUST USE THIS TIPPING RESTRAINT TO ATTACH THIS UNIT TO THE WALL, TO PREVENT ACCIDENTS AND/OR INJURIES. 18. The console is now prepared for use. Be positive to place your Flat Panel TV in middle of console. NOTE: For Universal Wall Mount, continue to PAGE #20.Position the assembled console on the favored place in opposition to a wall. If necessary, modify the pre-connected Floor Levelers at the lowest of Legs (F and G) to stage the unit. Now, comply with the commands imprinted on the plastic bag containing the Tipping Restraint Hardware to connect the tip-over restraint to the Top Metal Frame (A) and the wall. NOTE: YOU MUST USE THIS TIPPING RESTRAINT TO ATTACH THIS UNIT TO THE WALL, TO PREVENT ACCIDENTS AND/OR INJURIES. 18. The console is now prepared for use. Be positive to place your Flat Panel TV in middle of console. NOTE: For Universal Wall Mount, continue to PAGE #20.Position the assembled console on the favored place in opposition to a wall. If necessary, modify the pre-connected Floor Levelers at the lowest of Legs (F and G) to stage the unit. Now, comply with the commands imprinted on the plastic bag containing the Tipping Restraint Hardware to connect the tip-over restraint to the Top Metal Frame (A) and the wall. NOTE: YOU MUST USE THIS TIPPING RESTRAINT TO ATTACH THIS UNIT TO THE WALL, TO PREVENT ACCIDENTS AND/OR INJURIES. 18. The console is now prepared for use. Be positive to place your Flat Panel TV in middle of console. NOTE: For Universal Wall Mount, continue to PAGE #20.Position the assembled console on the favored place in opposition to a wall. If necessary, modify the pre-connected Floor Levelers at the lowest of Legs (F and G) to stage the unit. Now, comply with the commands imprinted on the plastic bag containing the Tipping Restraint Hardware to connect the tip-over restraint to the Top Metal Frame (A) and the wall. NOTE: YOU MUST USE THIS TIPPING RESTRAINT TO ATTACH THIS UNIT TO THE WALL, TO PREVENT ACCIDENTS AND/OR INJURIES. 18. The console is now prepared for use. Be positive to place your Flat Panel TV in middle of console. NOTE: For Universal Wall Mount, continue to PAGE #20.Position the assembled console on the favored place in opposition to a wall. If necessary, modify the pre-connected Floor Levelers at the lowest of Legs (F and G) to stage the unit. Now, comply with the commands imprinted on the plastic bag containing the Tipping Restraint Hardware to connect the tip-over restraint to the Top Metal Frame (A) and the wall. NOTE: YOU MUST USE THIS TIPPING RESTRAINT TO ATTACH THIS UNIT TO THE WALL, TO PREVENT ACCIDENTS AND/OR INJURIES. 18. The console is now prepared for use. Be positive to place your Flat Panel TV in middle of console. NOTE: For Universal Wall Mount, continue to PAGE #20.'
values = get_document_embedding(doc)
print(values)
print(len(values))

doc = 'Position the assembled console on the favored place in opposition to a wall. If necessary, modify the pre-connected Floor Levelers at the lowest of Legs (F and G) to stage the unit. Now, comply with the commands imprinted on the plastic bag containing the Tipping Restraint Hardware to connect the tip-over restraint to the Top Metal Frame (A) and the wall. NOTE: YOU MUST USE THIS TIPPING RESTRAINT TO ATTACH THIS UNIT TO THE WALL, TO PREVENT ACCIDENTS AND/OR INJURIES. 18. The console is now prepared for use. Be positive to place your Flat Panel TV in middle of console. NOTE: For Universal Wall Mount, continue to PAGE #20.'
values = get_document_embedding(doc)
print(values)
print(len(values))
# Out:
# [-0.7306084036827087, -0.18860933184623718, -0.5668705701828003, -0.12583096325397491, -0.4815761148929596, -0.23495300114154816, 0.2413165122270584, 0.10017451643943787, 0.815537691116333, 0.3223471939563751, -0.045006368309259415, -0.5202738046646118, 0.9102457761764526, 0.4059804081916809, 0.9610440731048584, -0.5231560468673706, 0.3346404433250427, 0.12207643687725067, -0.48302823305130005, -0.7110514640808105, -0.560883104801178, 0.6934150457382202, -0.4484930634498596, -0.7592999935150146, -0.8257707357406616, 2.1919326782226562, -0.19312316179275513, -0.9600790739059448, -0.9531443119049072, 0.5141845345497131, -0.9129605293273926, 0.115332692861557, 0.22372466325759888, 0.33958980441093445, -0.694820761680603, -0.379685640335083, 0.9266440868377686, 0.038638703525066376, -0.5495030879974365, -0.7545931339263916, 0.7236580848693848, -0.4136699438095093, 0.007231418043375015, 0.17035813629627228, 1.1516788005828857, -0.14916153252124786, -0.5590603351593018, 1.0414646863937378,
# ...

# %%
df = pd.read_csv('/Users/carina/Downloads/courses/final thesis/dataset/annotated text.csv')

# %%
df_vec = pd.DataFrame()
for index in df:
    para = df[index].tolist()
    final_vec = []
    for i in tqdm(range(len(para))):
        document = para[i]
        embedding = get_document_embedding(document)
        final_vec.append(embedding)
    df_vec[index] = final_vec
# Out:
# ...
# 100%|█████████████████████████████████████████| 480/480 [05:51<00:00,  1.36it/s]

# %%
df_vec
# Out:
#                                              paragraph  \
# 0    [0.5288379788398743, -1.1708874702453613, -0.3...
# 1    [0.5465728640556335, -1.249648928642273, -0.21...
# 2    [0.92889803647995, 0.060952138155698776, -1.62...
# 3    [0.4554034173488617, -1.114106297492981, -0.86...
# 4    [0.7283823490142822, -1.4775747060775757, -1.0...
# ..                                                 ...
# 475  [-1.4104852676391602, -0.002489360747858882, 0...
# 476  [-1.0955225229263306, 0.3022449314594269, -1.5...
# 477  [-1.619489073753357, -0.27995169162750244, -0....
# 478  [-1.3474867343902588, -0.3217661380767822, -0....
# 479  [-0.9298564195632935, 0.20895425975322723, -0....
#
#                                               rephrase  \
# 0    [0.03304337337613106, -0.5371646881103516, -0....
# 1    [0.18796035647392273, -0.4540446102619171, -0....
# 2    [0.543063223361969, -0.07667125761508942, -1.4...
# 3    [0.27076882123947144, -0.527903139591217, -0.6...
# ...

# %%
df_vec.to_csv('/Users/carina/Downloads/courses/final thesis/precessed data/doc2vec_xlnet.csv')

# %%
print(len(df_vec['paragraph'][0]))
# Out:
# 768
