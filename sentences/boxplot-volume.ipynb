# %%
import csv
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import textstat

# %%
WATs = ['Rephrase','Grammarly','ChatGPT','Wordtune','Quillbot']

df = pd.read_csv('/Users/carina/Downloads/courses/final thesis/precessed data/ex2/resultvolume/ALBERT.csv')
df = df.drop(df.columns[0],axis=1)
df.columns = WATs

df1 = pd.read_csv('/Users/carina/Downloads/courses/final thesis/precessed data/ex2/resultvolume/senBERT.csv')
df1 = df1.drop(df1.columns[0],axis=1)
df1.columns = WATs

heads = df.columns.values.tolist()    # 列名称

source = ['NLP paper','Literature','News','Encyclopedias','Social Media','Speeches','Interview','Instruction Manuals']

source_name = []
for i in range(len(source)):
    temsouce = [source[i]] * 60
    source_name = source_name + temsouce

# %% [markdown]
# # normalized results of volume

# %%
volume_data = pd.DataFrame()
tool_name = []
LM1= ['ALBERT'] * 480
LM2= ['senBERT'] * 480
LM = LM1 + LM2
LM_name = []
value = []
value0 = []
for head in heads:
    value_GPT2 = []
    value_BERT = []
    tem_value_GPT2 = []
    tem_value_GPT2 = df[head].tolist()
    tem_value_BERT = []
    tem_value_BERT = df1[head].tolist()
    for item in tem_value_GPT2:
        value_GPT2.append(item)
        tool_name.append(head)
    for item in tem_value_BERT:
        value_BERT.append(item)
        tool_name.append(head)
    LM_name = LM_name + LM
    value0 = value0 + value_GPT2 + value_BERT
    value = (value0 - np.mean(value0)) / np.std(value0)

volume_data['volume'] = value
volume_data['WATs'] = tool_name
volume_data['LM'] = LM_name

sns.violinplot(x="WATs", y="volume",hue="LM",data=volume_data,palette="Set3",width=0.5, linewidth=1.0) 
plt.legend(loc = 2, bbox_to_anchor = (1,1))
plt.figure(figsize=(1,1))

# %%
sns.boxplot(x="WATs", y="volume",hue="LM",data=volume_data,palette="Set3",width=0.5, linewidth=1.0) 
plt.legend(loc = 2, bbox_to_anchor = (1,1))
plt.figure(figsize=(1,1))

# %% [markdown]
# # results of volume

# %%
volume_data = pd.DataFrame()
tool_name = []
LM1= ['ALBERT'] * 480
LM2= ['senBERT'] * 480
LM = LM1 + LM2
LM_name = []
value = []
value0 = []
for head in heads:
    value_GPT2 = []
    value_BERT = []
    tem_value_GPT2 = []
    tem_value_GPT2 = df[head].tolist()
    tem_value_BERT = []
    tem_value_BERT = df1[head].tolist()
    for item in tem_value_GPT2:
        value_GPT2.append(item)
        tool_name.append(head)
    for item in tem_value_BERT:
        value_BERT.append(item)
        tool_name.append(head)
    LM_name = LM_name + LM
    value0 = value0 + value_GPT2 + value_BERT

volume_data['volume'] = value0
volume_data['WATs'] = tool_name
volume_data['LM'] = LM_name

sns.violinplot(x="WATs", y="volume",hue="LM",data=volume_data,palette="Set3",width=0.5, linewidth=1.0) 
plt.legend(loc = 2, bbox_to_anchor = (1,1))
plt.figure(figsize=(3,5))

# %%
sns.boxplot(x="WATs", y="volume",hue="LM",data=volume_data,palette="Set3",width=0.5, linewidth=1.0) 
plt.legend(loc = 2, bbox_to_anchor = (1,1))
plt.figure(figsize=(1,1))

# %% [markdown]
# # normalized results of volume-LM dependent

# %%
volume_data_GPT2 = pd.DataFrame()
volume_data_BERT = pd.DataFrame()
tool_name_GPT2 = []
tool_name_BERT = []
final_value_GPT2 = []
final_value_BERT = []
for head in heads:
    value_GPT2 = []
    value_BERT = []
    tem_value_GPT2 = []
    tem_value_GPT2 = df[head].tolist()
    tem_value_BERT = []
    tem_value_BERT = df1[head].tolist()
    for item in tem_value_GPT2:
        value_GPT2.append(item)
        tool_name_GPT2.append(head)
    for item in tem_value_BERT:
        value_BERT.append(item)
        tool_name_BERT.append(head)
    final_value_GPT2 = final_value_GPT2 + value_GPT2
    final_value_GPT2_ = (final_value_GPT2 - np.mean(final_value_GPT2)) / np.std(final_value_GPT2)
    final_value_BERT = final_value_BERT + value_BERT
    final_value_BERT_ = (final_value_BERT - np.mean(final_value_BERT)) / np.std(final_value_BERT)
    
volume_data_GPT2['volume'] = final_value_GPT2_
volume_data_GPT2['WATs'] = tool_name_GPT2
volume_data_BERT['volume'] = final_value_BERT_
volume_data_BERT['WATs'] = tool_name_BERT

f, axes = plt.subplots(1,2,sharex=True, figsize=(12,5))

a = sns.violinplot(x="WATs", y="volume",data=volume_data_GPT2,palette="Set3",width=0.5, linewidth=1.0,ax=axes[0])
a.set(title='ALBERT')
b = sns.violinplot(x="WATs", y="volume",data=volume_data_BERT,palette="Set3",width=0.5, linewidth=1.0,ax=axes[1])
b.set(title='senBERT')
# Out:
# [Text(0.5, 1.0, 'senBERT')]

# %% [markdown]
# # results of volume-LM dependent

# %%
volume_data_GPT2 = pd.DataFrame()
volume_data_BERT = pd.DataFrame()
tool_name_GPT2 = []
tool_name_BERT = []
final_value_GPT2 = []
final_value_BERT = []
for head in heads:
    value_GPT2 = []
    value_BERT = []
    tem_value_GPT2 = []
    tem_value_GPT2 = df[head].tolist()
    tem_value_BERT = []
    tem_value_BERT = df1[head].tolist()
    for item in tem_value_GPT2:
        value_GPT2.append(item)
        tool_name_GPT2.append(head)
    for item in tem_value_BERT:
        value_BERT.append(item)
        tool_name_BERT.append(head)
    final_value_GPT2 = final_value_GPT2 + value_GPT2
    final_value_BERT = final_value_BERT + value_BERT
    
volume_data_GPT2['volume'] = final_value_GPT2
volume_data_GPT2['WATs'] = tool_name_GPT2
volume_data_BERT['volume'] = final_value_BERT
volume_data_BERT['WATs'] = tool_name_BERT

f, axes = plt.subplots(2,1,sharex=False, figsize=(8,10))

a = sns.violinplot(x="WATs", y="volume",data=volume_data_GPT2,palette="Set3",width=0.5, linewidth=1.0,ax=axes[0])
a.set(title='ALBERT')
b = sns.violinplot(x="WATs", y="volume",data=volume_data_BERT,palette="Set3",width=0.5, linewidth=1.0,ax=axes[1])
b.set(title='senBERT')
# Out:
# [Text(0.5, 1.0, 'senBERT')]

# %% [markdown]
# # results of volume-source LM dependent

# %%
source_name_GPT2 = []
source_name_BERT = []
volume_data_GPT2 = pd.DataFrame()
volume_data_BERT = pd.DataFrame()
tool_name_GPT2 = []
tool_name_BERT = []
final_value_GPT2 = []
final_value_BERT = []
for head in heads:
    value_GPT2 = []
    value_BERT = []
    tem_value_GPT2 = []
    tem_value_GPT2 = df[head].tolist()
    tem_value_BERT = []
    tem_value_BERT = df1[head].tolist()
    for item in tem_value_GPT2:
        value_GPT2.append(item)
        tool_name_GPT2.append(head)

    for item in tem_value_BERT:
        value_BERT.append(item)
        tool_name_BERT.append(head)
    final_value_GPT2 = final_value_GPT2 + value_GPT2
    final_value_BERT = final_value_BERT + value_BERT
    source_name_GPT2 = source_name_GPT2 + source_name
    source_name_BERT = source_name_BERT + source_name
    
volume_data_GPT2['volume'] = final_value_GPT2
volume_data_GPT2['WATs'] = tool_name_GPT2
volume_data_GPT2['Sources'] = source_name_GPT2
volume_data_BERT['volume'] = final_value_BERT
volume_data_BERT['WATs'] = tool_name_BERT
volume_data_BERT['Sources'] = source_name_BERT

'''fig, axs = plt.subplots(2, 4, figsize=(20,10), sharey=True, sharex=False)
#fig.suptitle('volume result by ALBERT')

for i in range(2):
    for j in range(4):
        p = i * 4 + j
        subtitle = source[p]
        tem_Df = volume_data_GPT2[volume_data_GPT2['Sources'] == subtitle]

        sns.violinplot(y="WATs", x="volume", data=tem_Df, vert=False, showmeans=False,
                       showmedians=False, showextrema=False, ax=axs[i][j])
        axs[i][j].set_xlabel("")
        axs[i][j].set_ylabel("")

        #axs[i][j].set_yticklabels(fontproperties = 'Times New Roman', size = 320)
        #axs[i][j].set_xticklabels([],fontproperties = 'Times New Roman', size = 20)
        axs[i][j].tick_params(axis="x", labelsize=20)
        axs[i][j].tick_params(axis="y", labelsize=30)

        axs[i][j].set_title(subtitle,size=25)
plt.savefig('/Users/carina/Downloads/courses/final thesis/figures of results/sentence/volume/volume ALBERT.pdf', format = 'pdf',dpi = 500,bbox_inches='tight')

plt.show()'''

fig, axs = plt.subplots(2, 4, figsize=(20,10), sharey=True, sharex=False)
#fig.suptitle('volume result by senBERT')
for i in range(2):
    for j in range(4):
        p = i * 4 + j
        subtitle = source[p]
        tem_Df = volume_data_BERT[volume_data_BERT['Sources'] == subtitle]

        sns.violinplot(y="WATs", x="volume", data=tem_Df, vert=False, showmeans=False,
                       showmedians=False, showextrema=False, ax=axs[i][j])
        axs[i][j].set_xlabel("")
        axs[i][j].set_ylabel("")

        #axs[i][j].set_yticklabels(fontproperties = 'Times New Roman', size = 320)
        #axs[i][j].set_xticklabels([],fontproperties = 'Times New Roman', size = 20)
        axs[i][j].tick_params(axis="x", labelsize=20)
        axs[i][j].tick_params(axis="y", labelsize=30)

        axs[i][j].set_title(subtitle,size=25)
plt.savefig('/Users/carina/Downloads/courses/final thesis/figures of results/sentence/volume/volume senBERT.pdf', format = 'pdf',dpi = 500,bbox_inches='tight')

plt.show()
