# %%
#pip install scikit-learn-extra
import pandas as pd
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
import numpy as np
from tqdm import tqdm

# %%
def get_float_senBERT_vector(vectorstrlist):
    float_vectors = []
    for item in vectorstrlist:
        item = item.replace(" ","").replace("\n","")
        item = item.strip("(").strip(")").strip("[").strip("]")
        item = item.split(',')[0:384]
        item[383] = item[383].strip(']')
        item = [float(x) for x in item]
        #print(item)
        float_vectors.append(item)
    return float_vectors

# %%
df_allvectors = pd.read_csv('/Users/carina/Downloads/courses/final thesis/precessed data/ex3/senvec_senBERT.csv')
df_allvectors = df_allvectors.drop(df_allvectors.columns[0],axis=1)
heads = df_allvectors.columns.values.tolist()

# %%
all_central_points = pd.DataFrame()
for head in heads:
    allvectors = df_allvectors[head].tolist()
    length = len(allvectors)
    
    central_points = []
    for i in tqdm(range(length)):
        vectors = allvectors[i]
        vectors = vectors.strip("[").strip("]").split('array')
        vectors = [x for x in vectors if len(x) != 0]
        vectors = get_float_senBERT_vector(vectors)
        #print(vectors)
        # Set the number of clusters
        k = 1

        # Initialize and fit the KMedoids model
        kmedoids = KMedoids(n_clusters=k, random_state=0)
        kmedoids.fit(vectors)
        # Get the cluster medoids
        medoids = kmedoids.cluster_centers_
        central_points.append(medoids)

        #Print the results
        #print("Medoids:\n", medoids)
    all_central_points[head] = central_points
# Out:
# 100%|████████████████████████████████████████| 480/480 [00:00<00:00, 486.69it/s]
# 100%|████████████████████████████████████████| 480/480 [00:00<00:00, 527.82it/s]
# 100%|████████████████████████████████████████| 480/480 [00:00<00:00, 525.25it/s]
# 100%|████████████████████████████████████████| 480/480 [00:00<00:00, 623.25it/s]
# 100%|████████████████████████████████████████| 480/480 [00:00<00:00, 543.31it/s]
# 100%|████████████████████████████████████████| 480/480 [00:00<00:00, 504.86it/s]

# %%
all_central_points.to_csv('')

# %%
def get_floatvec_ALBERT(vecslist):
    vecslist = vecslist.split('],')
    float_vecs = []
    for item in vecslist:
        item = item.strip('[').strip(']').replace(' ','')
        item = item.split(',')
        single_values = []
        for vecs in item:
            vecs = vecs.strip('[')
            single_values.append(vecs)
        single_values = [float(x) for x in single_values]
        float_vecs.append(single_values)
    return float_vecs

# %%
df_allvectors = pd.read_csv('/Users/carina/Downloads/courses/final thesis/precessed data/ex3/senvec_ALBERT.csv')
df_allvectors = df_allvectors.drop(df_allvectors.columns[0],axis=1)
heads = df_allvectors.columns.values.tolist()

# %%
all_central_points = pd.DataFrame()
for head in heads:
    allvectors = df_allvectors[head].tolist()
    length = len(allvectors)
    
    central_points = []
    for i in tqdm(range(length)):
        vectors = allvectors[i]
        vectors = get_floatvec_ALBERT(vectors)
        #print(vectors)
        # Set the number of clusters
        k = 1
        
        if len(vectors) == 0 :
            print('chucule')
            vectors = [[0.0 for i in range(768)] for j in range(15)]

        # Initialize and fit the KMedoids model
        kmedoids = KMedoids(n_clusters=k, random_state=0)
        kmedoids.fit(vectors)
        # Get the cluster medoids
        medoids = kmedoids.cluster_centers_
        central_points.append(medoids)

        #Print the results
        #print("Medoids:\n", medoids)
    all_central_points[head] = central_points
# Out:
# 100%|████████████████████████████████████████| 480/480 [00:02<00:00, 192.16it/s]
# 100%|████████████████████████████████████████| 480/480 [00:02<00:00, 197.43it/s]
# 100%|████████████████████████████████████████| 480/480 [00:02<00:00, 200.64it/s]
# 100%|████████████████████████████████████████| 480/480 [00:01<00:00, 256.64it/s]
# 100%|████████████████████████████████████████| 480/480 [00:02<00:00, 211.72it/s]
# 100%|████████████████████████████████████████| 480/480 [00:02<00:00, 193.66it/s]

# %%
all_central_points['paragraph'][0]
# Out:
# array([[ 8.80964279e-01,  6.23058021e-01,  3.18653822e-01,
#         -1.29486740e-01, -1.87528983e-01, -7.51980841e-01,
#         -6.43403769e-01, -7.81011224e-01, -9.58365649e-02,
#          1.16561925e+00,  7.12193489e-01,  9.86357331e-01,
#          3.39820296e-01,  2.68826485e-01, -3.76011819e-01,
#          5.41012406e-01,  2.20965043e-01,  3.64344642e-02,
#          1.86692834e-01,  3.60420406e-01,  1.68542361e+00,
#         -2.57599831e+00, -1.56691313e-01,  2.16552913e-02,
#          7.47412145e-02, -5.98985493e-01,  2.74553359e-01,
#         -2.60993361e-01,  9.64031756e-01, -1.70161891e+00,
#         -5.58852434e-01,  1.05598664e+00,  5.03118038e-01,
#         -1.28323287e-01, -2.04956722e+00, -1.83768344e+00,
#          8.52728635e-03,  3.73985887e-01,  2.39456713e-01,
#         -6.80721462e-01,  4.44846302e-01,  1.19351757e+00,
#         -7.27857530e-01, -1.61930367e-01,  1.24602556e+00,
#          1.15411508e+00, -9.13323879e-01,  5.57175517e-01,
#          5.85785747e-01,  8.17962587e-02,  3.59987795e-01,
#         -1.99067175e-01,  4.09510583e-01,  1.04051912e+00,
#          1.34060800e+00,  4.49300289e-01, -7.74611160e-02,
#          9.20510530e-01,  2.55364120e-01,  6.78957105e-01,
#         -8.10317248e-02, -1.49181557e+00, -1.79182172e-01,
#          2.96128392e-01, -4.30873670e-02,  1.17198539e+00,
#          7.31103659e-01,  8.55328023e-01,  4.23246324e-02,
#         -5.65842092e-01,  1.31519467e-01, -4.19679821e-01,
#         -1.64102638e+00, -7.67611504e-01, -1.24652791e+00,
#         -5.82331240e-01,  2.67316484e+00, -7.95572281e-01,
#          1.43130556e-01,  1.28419256e+00, -5.71496263e-02,
#          9.79356885e-01, -7.67610490e-01, -2.13211679e+00,
#          1.37106919e+00,  4.14800137e-01, -1.72382370e-01,
#         -1.00871706e+00, -5.91901064e-01, -1.83951819e+00,
#          8.61294866e-01, -2.22921893e-01,  5.35451829e-01,
#          1.80747300e-01, -5.69972456e-01, -1.10517263e-01,
#          1.49760175e+00,  2.25110665e-01, -7.84192324e-01,
#          3.34922448e-02, -5.88517249e-01, -9.53670681e-01,
#          1.68878591e+00, -4.16764617e-01,  3.30500245e-01,
#          4.25670952e-01,  1.56361556e+00, -6.73010707e-01,
#          1.25943542e-01, -7.01724589e-01,  1.10864973e+00,
#          6.28331304e-01,  5.60389698e-01,  3.88214499e-01,
#          2.10416779e-01,  1.09775610e-01, -1.28502107e+00,
#          1.47118974e+00, -6.80571318e-01,  8.40060472e-01,
#          1.06045353e+00,  5.36723062e-02,  2.81485468e-01,
#          7.30250329e-02,  8.24678540e-02,  1.69229507e+00,
#          1.89920515e-02,  5.87649405e-01,  1.79001141e+00,
#         -2.15127420e+00, -8.81251216e-01, -4.81145591e-01,
#          6.19165003e-01, -3.74456719e-02,  7.55049467e-01,
#          9.33620453e-01, -5.67381859e-01, -2.02114487e+00,
#          1.56925225e+00, -6.81192875e-01,  1.11360157e+00,
#         -1.51518595e+00, -1.57406771e+00,  2.60346178e-02,
#         -1.52411371e-01,  7.77889788e-01, -2.47379756e+00,
#          4.08611536e-01,  7.30357170e-01, -1.47218955e+00,
#          4.82989430e-01, -8.23087215e-01, -6.51066080e-02,
#          4.64547336e-01, -7.92702019e-01,  2.12881613e+00,
#         -1.06637943e+00, -5.21054983e-01, -3.45897406e-01,
#         -6.83934569e-01, -3.54413353e-02, -7.66909420e-01,
#         -2.24825650e-01, -1.76381320e-01,  2.73300290e-01,
#          1.69127598e-01, -7.95351744e-01, -1.82832956e-01,
#         -7.51076698e-01, -1.77080259e-01, -9.89209861e-02,
#          8.17318320e-01, -1.66889191e+00, -1.16825104e-02,
#          6.54786289e-01,  1.08354187e+00,  2.57628262e-01,
#          6.29363209e-02, -1.81581765e-01,  3.91858399e-01,
#         -1.29966676e+00, -1.06985398e-01, -4.40865636e-01,
#         -2.16871428e+00,  1.02691934e-01,  2.59908289e-01,
#          5.16871274e-01,  1.20914103e-02,  6.08247042e-01,
#          2.26294547e-02,  3.65464240e-02, -9.63414669e-01,
#          5.03643870e-01,  2.69598842e-01, -7.89323926e-01,
#         -1.53281033e+00, -4.05301929e-01, -7.33030364e-02,
#          1.39843315e-01, -1.25996172e+00,  3.68693054e-01,
#          6.29568323e-02,  1.58541298e+00,  5.24548173e-01,
#          1.20788908e+00,  8.18985641e-01, -3.46199393e-01,
#          1.55590916e+00,  1.00344193e+00,  1.11047161e+00,
#          6.45737171e-01, -1.12939215e+00, -1.61835507e-01,
#         -1.15021214e-01,  8.56654048e-01, -6.10092342e-01,
#         -1.14431751e+00,  5.23347676e-01, -1.34457111e+00,
#         -8.63916874e-01,  4.34968561e-01,  1.40370119e+00,
#          1.05953896e+00,  1.79182470e-01, -1.05952168e+00,
#         -1.93216696e-01,  6.81692421e-01, -1.44742930e+00,
#         -2.51999527e-01, -1.07664764e+00,  1.30564737e+00,
#         -1.08346725e+00, -6.73743486e-01, -1.32963634e+00,
#         -3.98668319e-01, -1.11244604e-01,  3.54435623e-01,
#          3.16496432e-01, -8.88552904e-01, -7.92817771e-03,
#          5.79033792e-02,  4.50068712e-01,  1.70326218e-01,
#         -5.85502535e-02, -5.21839619e-01, -7.82381058e-01,
#          1.00810170e+00, -9.82251287e-01,  1.90852273e+00,
#          5.57592344e+00,  1.96971804e-01, -7.88413882e-01,
#         -6.34096384e-01,  8.16741884e-01, -2.14106798e-01,
#         -1.25639737e+00, -1.20821035e+00,  1.07197249e+00,
#          6.23530197e+00, -4.13040876e-01, -1.01581991e+00,
#          2.35415727e-01, -2.08354950e-01, -8.37429464e-01,
#          3.35289806e-01, -7.27543175e-01,  2.76830316e-01,
#         -2.23141223e-01, -2.22493792e+00, -9.64468598e-01,
#          3.77827376e-01, -2.11111963e-01, -7.11032271e-01,
#         -1.22151256e+00, -2.52098918e-01,  1.56241798e+00,
#         -5.59076011e-01, -2.03673005e+00,  4.74673361e-01,
#         -1.36893678e+00,  2.29589596e-01, -1.39780819e+00,
#          9.27426994e-01, -9.82508540e-01, -1.10604143e+00,
#         -2.14998722e+00, -4.36630368e-01,  7.67893314e-01,
#          2.89044708e-01, -4.76749092e-02, -1.11400831e+00,
#         -5.31937122e-01,  8.83182466e-01, -1.81827575e-01,
#         -2.11523041e-01,  7.10476041e-01,  1.38815534e+00,
#         -1.06144285e+00,  5.17651498e-01, -5.16554713e-01,
#         -1.28308105e+00,  2.73379731e+00,  1.21452785e+00,
#          1.03030354e-01,  1.00003254e+00,  5.58419764e-01,
#          1.97055280e-01, -8.32040370e-01, -1.83544397e+00,
#         -1.43843412e+00,  1.19098806e+00,  1.09844708e+00,
#          2.14092702e-01,  1.56816709e+00,  1.51900315e+00,
#          2.41568494e+00,  1.32928181e+00, -1.24498212e+00,
#         -1.07670021e+00, -3.07966769e-01, -1.44168806e+00,
#         -8.47476840e-01,  3.86775225e-01,  4.25717264e-01,
#          1.54625624e-01, -9.00416493e-01, -2.64031649e-01,
#         -2.56719995e+00, -9.86616313e-03,  1.70663977e+00,
#          6.55122995e-01,  1.57183409e+00, -7.86293864e-01,
#          1.98308313e+00, -7.59863853e-01, -4.56360839e-02,
#          1.04362321e+00, -9.62336898e-01,  1.51861930e+00,
#         -8.94540548e-01, -5.50487161e-01, -9.21849668e-01,
#          8.58000368e-02, -3.59439552e-01,  8.16816688e-02,
#          1.71887845e-01, -1.52384138e+00, -4.06529069e-01,
#          4.82969314e-01, -1.69204021e+00, -2.56786317e-01,
#         -8.11865151e-01, -5.11719704e-01,  5.15210688e-01,
#         -2.86172032e-02, -1.84553370e-01, -1.13122618e+00,
#         -2.09331846e+00, -2.47836903e-01, -7.44594932e-01,
#          3.64518687e-02,  4.95228648e-01, -4.37345892e-01,
#          5.89625202e-02,  9.49889123e-02,  4.65079010e-01,
#         -1.02537632e+00, -7.82917917e-01, -2.47723982e-01,
#          1.73087820e-01, -3.46079707e+00,  1.51569033e+00,
#         -2.12561822e+00, -5.06156087e-01, -8.88331473e-01,
#          5.98558068e-01,  1.14821458e+00, -1.01767516e+00,
#         -4.17978525e-01, -3.50182295e-01, -1.04629481e+00,
#         -8.94167721e-02,  5.40844798e-01, -1.22873425e+00,
#         -2.40354091e-01, -2.59279251e-01, -6.74623489e-01,
#         -1.28549457e+00,  3.07074577e-01,  1.07257530e-01,
#         -8.49740952e-02, -6.24881908e-02,  5.02764583e-01,
#          8.16165924e-01,  1.14263296e+00, -2.59180874e-01,
#         -3.21594417e-01, -1.33565366e-01, -5.56617796e-01,
#         -5.58967710e-01,  1.01695716e+00, -1.00615108e+00,
#          8.13420355e-01,  4.39162552e-02,  1.28885165e-01,
#          1.33635843e+00,  2.15351129e+00, -9.01077330e-01,
#         -3.72218549e-01,  6.70910716e-01, -6.62085176e-01,
#         -1.18111581e-01,  1.85522005e-01,  2.86781132e-01,
#         -6.61049128e-01,  3.46817994e+00,  2.36128187e+00,
#         -9.61760581e-01, -1.31242716e+00,  6.08040631e-01,
#         -1.62592554e+00,  6.24115884e-01, -2.11484694e+00,
#          7.55739510e-01,  6.91977441e-01, -4.64840889e-01,
#          2.26746202e+00, -6.80610776e-01, -9.78192210e-01,
#          7.48982131e-01, -5.80614567e-01,  5.00848472e-01,
#          1.72317386e-01,  2.05675140e-01, -3.09610367e-03,
#          1.46165419e+00,  1.01183581e+00,  3.41377079e-01,
#          1.09403467e+00,  1.51986569e-01,  3.52743924e-01,
#          9.94383037e-01, -9.49607134e-01,  6.13122702e-01,
#          3.31637025e-01, -3.74479219e-02,  1.15358710e+00,
#          7.26449847e-01,  2.71395516e+00,  1.34628147e-01,
#          3.67105544e-01, -2.59233207e-01,  3.53813767e-01,
#         -4.26076710e-01,  8.74886870e-01,  6.61130965e-01,
#         -4.63312507e-01,  4.89087611e-01,  1.69447803e+00,
#         -1.58272052e+00, -8.40355337e-01, -8.76269341e-01,
#         -2.87080169e-01,  4.53431338e-01,  4.13710997e-02,
#          8.00035670e-02, -8.61037016e-01, -2.15354800e-01,
#          1.81366444e-01, -1.79914677e+00, -9.06752050e-03,
#         -1.03646266e+00, -5.08231938e-01,  7.05220163e-01,
#          7.95944273e-01, -5.19701242e-02, -4.53760058e-01,
#          1.33623973e-01, -1.02118754e+00,  2.54959762e-01,
#          1.12923181e+00, -1.66442144e+00, -7.63305485e-01,
#         -9.34721977e-02, -3.78035642e-02, -8.89249444e-01,
#         -2.75154915e-02, -1.17473555e+00,  5.73823094e-01,
#          3.36325675e-01, -7.38807321e-01, -1.84958547e-01,
#          1.73346758e-01, -6.23001635e-01, -7.82276750e-01,
#          3.79932344e-01,  8.90178144e-01,  3.13988924e-01,
#         -6.79846555e-02, -3.93269449e-01, -1.56023550e+00,
#          1.59573495e+00,  2.80992061e-01, -7.37377405e-01,
#         -9.82162118e-01,  4.80595827e-01,  8.66416693e-01,
#          7.23796427e-01,  1.18449524e-01, -7.50386357e-01,
#          5.28558195e-01,  4.31475997e-01, -1.05249977e+00,
#         -7.97153413e-01, -1.93329602e-01, -1.55628347e+00,
#         -9.10522580e-01, -4.61222827e-01,  5.56528211e-01,
#          3.01670402e-01, -7.89145291e-01,  1.15271401e+00,
#          9.92382348e-01, -2.38450199e-01, -1.22373557e+00,
#         -6.64499581e-01, -7.11487651e-01, -2.66833335e-01,
#         -7.84848392e-01,  5.53234637e-01,  6.50967836e-01,
#         -7.46909142e-01,  1.26784360e+00, -5.16332626e-01,
#          1.71822357e+00,  1.12549520e+00, -5.47257304e-01,
#         -9.78922099e-03,  3.61809701e-01, -8.04663837e-01,
#         -1.81033403e-01,  1.05535591e+00,  5.25988221e-01,
#         -1.01832116e+00, -6.13756001e-01,  1.70298472e-01,
#         -6.34736478e-01, -2.73485541e-01, -5.12162268e-01,
#          3.73974830e-01, -6.61533117e-01,  7.70760328e-02,
#         -2.28298277e-01, -6.38340652e-01, -3.82810831e-02,
#         -2.65217006e-01, -7.04426169e-01,  1.41437650e-01,
#          1.37307966e+00,  1.26484478e+00, -1.82023513e+00,
#          6.67055070e-01, -1.07646954e+00, -6.53742552e-01,
#          1.79459333e+00,  2.38973022e-01,  6.33885562e-01,
#          1.18005788e+00, -4.91057962e-01,  1.27065527e+00,
#         -2.13531518e+00,  1.24806428e+00, -1.26119196e-01,
#          1.89539170e+00,  7.76670814e-01, -2.84272790e-01,
#         -3.91182780e+00,  1.37037486e-01,  3.99979085e-01,
#          3.80125195e-01, -3.20525080e-01,  9.11198199e-01,
#         -1.66034311e-01,  8.65359485e-01,  2.91190386e-01,
#          4.05675590e-01, -1.19141638e+00,  8.03806663e-01,
#          1.70760500e+00, -7.38194585e-02,  9.71981108e-01,
#          4.05057073e-02, -9.49532747e-01,  6.56342983e-01,
#          5.94871163e-01,  1.53265262e+00, -5.26202202e-01,
#         -4.03288007e-02,  2.23810166e-01, -6.53280377e-01,
#          5.75151563e-01,  1.30911335e-01, -4.28002894e-01,
#          2.20522121e-01, -8.16134155e-01,  9.15150702e-01,
#         -3.54633555e-02, -4.83483493e-01,  1.16648841e+00,
#         -9.09413695e-01,  3.58172446e-01, -1.42975795e+00,
#         -1.47448897e+00,  7.70254433e-01, -1.28495967e+00,
#         -3.04581553e-01, -7.87704706e-01,  5.91711402e-01,
#         -9.35149193e-01,  8.58865455e-02,  1.46773112e+00,
#         -1.57391679e+00,  7.80357301e-01, -1.74601674e-02,
#          5.75047374e-01, -7.95087159e-01, -7.72112966e-01,
#         -1.57675183e+00,  2.34782860e-01, -5.03296494e-01,
#          1.35175419e+00, -6.46831810e-01, -4.39046174e-01,
#         -2.56388426e-01, -6.51155472e-01, -2.13757560e-01,
#          6.33915424e-01, -2.75999755e-01,  4.35792387e-01,
#          7.75488839e-03, -1.87080073e+00, -3.32783222e-01,
#         -8.32430422e-01, -4.57154870e-01, -7.30518103e-01,
#         -2.55497545e-01, -9.25163388e-01,  2.70919412e-01,
#         -1.99470890e+00, -1.64839017e+00, -8.80583644e-01,
#         -1.08722198e+00,  9.91311729e-01, -1.02313507e+00,
#         -3.33007663e-01, -9.33285058e-01, -9.76113796e-01,
#          7.84118026e-02,  1.97306395e-01, -7.09626675e-01,
#          1.20013225e+00, -7.20495701e-01, -7.85687327e-01,
#         -3.61440599e-01, -1.29560995e+00, -1.07342267e+00,
#          4.07023907e+00, -9.60081220e-01,  3.04486632e-01,
#          3.16055149e-01, -1.43833447e+00, -8.04747164e-01,
#          2.49750996e+00,  4.03953165e-01, -9.14863348e-01,
#         -3.37090254e-01,  2.40332150e+00, -9.21354294e-02,
#          4.94821779e-02,  1.64290714e+00, -1.39591157e+00,
#         -3.10176611e-03,  6.24935031e-01,  1.66139692e-01,
#          1.49369657e+00,  4.46783334e-01, -1.70800841e+00,
#          3.69609892e-01,  2.17682314e+00, -2.30125117e+00,
#         -4.60320294e-01, -4.24213558e-02,  2.82710671e-01,
#          4.17504162e-02, -4.30747926e-01, -1.33614171e+00,
#          7.48400092e-01,  7.31681705e-01, -5.08611381e-01,
#         -4.29717422e-01, -1.80569828e+00,  3.23175758e-01,
#          9.07473087e-01, -6.59202099e-01, -2.49244303e-01,
#          9.12071645e-01,  6.81356728e-01,  2.69348919e-01,
#          2.52549320e-01, -1.59300518e+00,  2.68984407e-01,
#          9.90909874e-01, -4.72641826e-01, -4.32024091e-01,
#          1.80859900e+00,  4.10787314e-01,  7.32629597e-01,
#         -9.42820609e-01,  7.73279667e+00,  1.10796459e-01,
#         -2.89237380e-01, -3.41869354e-01,  5.61159849e-01,
#         -9.46177304e-01,  5.37699521e-01, -1.47254556e-01,
#          8.22699368e-01, -1.56173670e+00, -1.90111279e+00,
#          3.78070354e-01,  9.49487269e-01,  3.11250508e-01,
#          3.99275690e-01,  9.40571487e-01,  2.43915364e-01,
#         -7.87057281e-01,  1.17562056e-01,  1.36473989e+00,
#          7.55880892e-01, -5.18169582e-01, -3.46960843e-01,
#          3.51224095e-01,  5.32200694e-01, -1.12381852e+00,
#         -1.06481457e+00, -2.26125193e+00,  1.56411529e-01,
#          1.62890956e-01,  9.04228032e-01,  6.22744322e-01,
#         -1.50777161e+00,  2.80328780e-01,  7.48211622e-01,
#         -1.28022945e+00, -5.08016527e-01,  9.35085297e-01,
#          1.57673240e+00,  1.22569108e+00, -5.98835945e-01,
#          3.71892899e-01, -6.98471546e-01,  6.80199683e-01,
#          3.78587246e-01, -6.39725745e-01, -1.01576537e-01,
#          1.26477942e-01, -1.24433923e+00,  6.74232900e-01]])

# %%
all_central_points.to_csv('/Users/carina/Downloads/courses/final thesis/precessed data/ex3/central_emvec_ALBERT.csv')
